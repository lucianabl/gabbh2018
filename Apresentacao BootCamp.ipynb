# %%
import pandas as pd
import numpy as np
import urllib.request
import json

# %%
data =  {

        "Inputs": {

                "input1":
                {
                    "ColumnNames": ["User ID", "Gender", "Age", "EstimatedSalary", "Purchased"],
                    "Values": [ [ "0", "Male", "30", "100000", None ], [ "0", "Female", "20", "50000", "0" ], ]
                },        },
            "GlobalParameters": {
}
    }

# %%
body = str.encode(json.dumps(data))

url = 'https://ussouthcentral.services.azureml.net/workspaces/435dd951be954060a21903a2c90739a1/services/49c9c56a754b45bebf6014f3cd07996b/execute?api-version=2.0&details=true'
api_key = 'IV1/3Xu+OI/0zByCuW5Q6tF+b+/6pA2/KxeMljlKC7Exk2jOLuSKJdYZObVAxFbveIWauaZzSEfyzAjgkhy67Q==' # Replace this with the API key for the web service
headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

req = urllib.request.Request(url, body, headers)

# %%
try:
    response = urllib.request.urlopen(req)

    result = response.read()
    print(result)
except urllib.error.HTTPError as error:
    print("The request failed with status code: " + str(error.code))

    # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
    print(error.info())
    print(json.loads(error.read().decode("utf8", 'ignore')))
# Out:
# b'{"Results":{"output1":{"type":"table","value":{"ColumnNames":["Genero","Idade","Salario","Comprou","Scored Labels","Scored Probabilities"],"ColumnTypes":["String","Double","Double","Nullable`1","Int32","Double"],"Values":[["Male","-0.731153005352982","0.888507148090176",null,"1","0.868243932723999"],["Female","-1.68628429908647","-0.579735681109487","0","0","1.56318437802838E-05"]]}}}}'
